# %% [markdown]
# <a href="https://colab.research.google.com/github/Firizki17/Machine-Learning/blob/main/Kuis2_MuhFirizkiipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eda

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('Smart Pressure Control Prediction.csv')

# %%
df.head()
# Out:
#    DEGC1PV  DEGC2PV  DEGC3PV  DEGC4PV  DEGC5PV  DEGC6PV  DEGC1SV  DEGC2SV  \
# 0   1022.0   1053.6   1240.2   1217.0   1165.3   1185.6   1005.0     1070
# 1   1019.2   1009.0   1215.5   1190.7   1133.6   1156.2   1005.0     1070
# 2    725.9    710.3    802.1    796.5    853.8    775.3   1050.2     1070
# 3    980.1   1032.2   1215.5   1189.0   1136.4   1161.0   1005.0     1070
# 4   1042.2   1023.1   1237.0   1183.7   1153.2   1103.4   1005.0     1070
#
#    DEGC3SV  DEGC4SV  ...  NM3/H.5SV  NM3/H.6SV   TEMP   FC1   FC2   FC3   FC4  \
# 0     1220     1200  ...       1370       6548  541.2  17.1  14.5  18.0  34.5
# 1     1210     1200  ...       2299       6548  505.2  13.7  15.8  20.3  35.2
# 2     1200     1180  ...       1900       3778  419.1  10.0   9.3   9.8  15.0
# 3     1220     1210  ...       2164       6465  529.1  15.7  14.9  18.0  36.4
# 4     1210     1200  ...        988       4624  549.8   8.8   7.0  15.0  20.0
#
#     FC5   FC6  mmH2O
# 0   4.3  53.6    501
# ...

# %%
df.shape
# Out:
# (3456, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3456 entries, 0 to 3455
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DEGC1PV    3456 non-null   float64
#  1   DEGC2PV    3456 non-null   float64
#  2   DEGC3PV    3456 non-null   float64
#  3   DEGC4PV    3456 non-null   float64
#  4   DEGC5PV    3456 non-null   float64
#  5   DEGC6PV    3456 non-null   float64
#  6   DEGC1SV    3456 non-null   float64
#  7   DEGC2SV    3456 non-null   int64
#  8   DEGC3SV    3456 non-null   int64
#  9   DEGC4SV    3456 non-null   int64
#  10  DEGC5SV    3456 non-null   int64
#  11  DEGC6SV    3456 non-null   int64
#  12  NM3/H.1PV  3456 non-null   int64
#  13  NM3/H.2PV  3456 non-null   int64
#  14  NM3/H.3PV  3456 non-null   int64
#  15  NM3/H.4PV  3456 non-null   int64
#  16  NM3/H.5PV  3456 non-null   int64
#  17  NM3/H.6PV  3456 non-null   int64
#  18  NM3/H.1SV  3456 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# DEGC1PV      0
# DEGC2PV      0
# DEGC3PV      0
# DEGC4PV      0
# DEGC5PV      0
# DEGC6PV      0
# DEGC1SV      0
# DEGC2SV      0
# DEGC3SV      0
# DEGC4SV      0
# DEGC5SV      0
# DEGC6SV      0
# NM3/H.1PV    0
# NM3/H.2PV    0
# NM3/H.3PV    0
# NM3/H.4PV    0
# NM3/H.5PV    0
# NM3/H.6PV    0
# NM3/H.1SV    0
# NM3/H.2SV    0
# NM3/H.3SV    0
# NM3/H.4SV    0
# NM3/H.5SV    0
# NM3/H.6SV    0
# TEMP         0
# FC1          0
# FC2          0
# FC3          0
# FC4          0
# FC5          0
# FC6          0
# mmH2O        0
# dtype: int64

# %% [markdown]
# # Data Understanding

# %%
df.columns
# Out:
# Index(['DEGC1PV', 'DEGC2PV', 'DEGC3PV', 'DEGC4PV', 'DEGC5PV', 'DEGC6PV',
#        'DEGC1SV', 'DEGC2SV', 'DEGC3SV', 'DEGC4SV', 'DEGC5SV', 'DEGC6SV',
#        'NM3/H.1PV', 'NM3/H.2PV', 'NM3/H.3PV', 'NM3/H.4PV', 'NM3/H.5PV',
#        'NM3/H.6PV', 'NM3/H.1SV', 'NM3/H.2SV', 'NM3/H.3SV', 'NM3/H.4SV',
#        'NM3/H.5SV', 'NM3/H.6SV', 'TEMP', 'FC1', 'FC2', 'FC3', 'FC4', 'FC5',
#        'FC6', 'mmH2O'],
#       dtype='object')

# %%
df.describe()
# Out:
#            DEGC1PV      DEGC2PV      DEGC3PV      DEGC4PV      DEGC5PV  \
# count  3456.000000  3456.000000  3456.000000  3456.000000  3456.000000
# mean    947.608478   960.971759  1124.749566  1100.605324  1074.780671
# std     131.106902   149.135565   172.270884   167.400860   153.216457
# min     474.100000   455.900000   551.600000   493.000000   525.700000
# 25%     886.650000   900.375000  1055.125000  1034.175000  1040.300000
# 50%     998.800000  1029.100000  1216.100000  1188.800000  1144.500000
# 75%    1027.825000  1056.525000  1226.825000  1203.200000  1161.100000
# max    1156.000000  1164.900000  1314.600000  1260.400000  1263.700000
#
#            DEGC6PV      DEGC1SV  DEGC2SV      DEGC3SV      DEGC4SV  ...  \
# count  3456.000000  3456.000000   3456.0  3456.000000  3456.000000  ...
# mean   1056.477054  1009.904514   1070.0  1214.780093  1201.338252  ...
# std     171.415432    14.060120      0.0     9.620631    10.021476  ...
# ...

# %%
# Attempt to describe only object columns
object_cols = df.select_dtypes(include='object').columns
if len(object_cols) > 0:
    object_description = df[object_cols].describe()
    print(object_description)
else:
    print("No columns with object data type found in the DataFrame.")

# To describe all columns, including numerical ones:
all_cols_description = df.describe(include='all')  # Use 'all' for all data types
print(all_cols_description)
# Out:
# No columns with object data type found in the DataFrame.
#            DEGC1PV      DEGC2PV      DEGC3PV      DEGC4PV      DEGC5PV  \
# count  3456.000000  3456.000000  3456.000000  3456.000000  3456.000000
# mean    947.608478   960.971759  1124.749566  1100.605324  1074.780671
# std     131.106902   149.135565   172.270884   167.400860   153.216457
# min     474.100000   455.900000   551.600000   493.000000   525.700000
# 25%     886.650000   900.375000  1055.125000  1034.175000  1040.300000
# 50%     998.800000  1029.100000  1216.100000  1188.800000  1144.500000
# 75%    1027.825000  1056.525000  1226.825000  1203.200000  1161.100000
# max    1156.000000  1164.900000  1314.600000  1260.400000  1263.700000
#
#            DEGC6PV      DEGC1SV  DEGC2SV      DEGC3SV      DEGC4SV  ...  \
# count  3456.000000  3456.000000   3456.0  3456.000000  3456.000000  ...
# mean   1056.477054  1009.904514   1070.0  1214.780093  1201.338252  ...
# ...

# %%
df.DEGC1PV.unique()
# Out:
# array([1022. , 1019.2,  725.9, ..., 1033.4,  487.6,  902.4])

# %% [markdown]
# # Data Visualization

# %% [markdown]
# UNVIVARIATE

# %%
plt.figure(figsize=(10,6))
# Assuming 'SalePrice' is the target variable you want to visualize
sns.distplot(df['DEGC6PV'], color='b')
plt.title('Distribution of DEGC6PV', size=18)
plt.xlabel('DEGC6PV', size=15)
plt.ylabel('Density', size=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.FC3)
plt.title('FC3 Distribution',size=18)
plt.xlabel('FC3',size=15)
plt.ylabel('Count',size=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df.mmH2O,color='y')
plt.title('mmH2O Distribution',size=18)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='TEMP', data=df)
plt.title('TEMP',size=18)
plt.xlabel('TEMP',size=15)
plt.show()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='FC6', data=df)
plt.title('FC6',size=18)
plt.xlabel('FC6',size=15)
plt.ylabel('Count',size=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='FC5', data=df)
plt.title('FC5',size=18)
plt.xlabel('FC5',size=15)
plt.ylabel('Count',size=15)
plt.show()

# %% [markdown]
# BIVARIATE

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='FC1', y='FC2', color = 'r', data=df)
plt.title('FC1 vs FC2',size=18)
plt.xlabel('FC',size=15)
plt.ylabel('Cond',size=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='DEGC1PV', y='DEGC2PV', data=df)
plt.title('DEGC1PV vs DEGC2PV',size=18)
# Out:
# Text(0.5, 1.0, 'DEGC1PV vs DEGC2PV')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='mmH2O', data=df)
plt.title('mmH2O',size=18)
# Out:
# Text(0.5, 1.0, 'mmH2O')

# %% [markdown]
# MULTIVARIABLE

# %%
plt.figure(figsize=(36,30))
numerical_df = df.select_dtypes(include=['number'])
sns.heatmap(numerical_df.corr(), annot=True, square=True)
plt.title('Correlation Between Variables', size=20)
plt.xticks(size=13)
plt.yticks(size=13)
plt.show()

# %% [markdown]
# Handling categorical missing values

# %%
# Select categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Replace missing values with the most frequent category (mode)
for col in categorical_cols:
    mode = df[col].mode()[0]  # Get the most common value
# Select categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Replace missing values with the most frequent category (mode)
for col in categorical_cols:
    mode = df[col].mode()[0]  # Get the most common value
    df[col].fillna(mode, inplace=True)  # Fill missing values

    print(df[categorical_cols])

# %% [markdown]
# ## Handling numeric missing values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

features = ['DEGC3PV', 'DEGC4PV', 'DEGC5PV']

# Plot box plots
df[features]=np.log(df[features])
df[features].boxplot(figsize=(8, 4))

plt.title('Box Plot for Outlier Detection')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
# Select numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns
for col in numerical_columns:
    median = df[col].median()
    df[col].fillna(median, inplace=True)  # Replace nulls with median
    print(df[col])
# Out:
# 0       1022.0
# 1       1019.2
# 2        725.9
# 3        980.1
# 4       1042.2
#          ...
# 3451     487.6
# 3452    1001.1
# 3453    1017.2
# 3454     902.4
# 3455     963.4
# Name: DEGC1PV, Length: 3456, dtype: float64
# 0       1053.6
# 1       1009.0
# 2        710.3
# 3       1032.2
# 4       1023.1
#          ...
# 3451     464.3
# 3452    1024.7
# 3453    1072.3
# 3454     922.9
# 3455    1035.2
# Name: DEGC2PV, Length: 3456, dtype: float64
# 0       7.123028
# 1       7.102911
# 2       6.687233
# 3       7.102911
# 4       7.120444
#           ...
# 3451    6.343880
# 3452    7.095230
# 3453    7.122463
# 3454    6.920079
# 3455    7.098376
# Name: DEGC3PV, Length: 3456, dtype: float64
# 0       7.104144
# 1       7.082297
# 2       6.680227
# 3       7.080868
# 4       7.076400
#           ...
# 3451    6.203143
# 3452    7.044469
# 3453    7.095976
# 3454    6.912345
# 3455    7.079690
# Name: DEGC4PV, Length: 3456, dtype: float64
# 0       7.060734
# ...

# %%
# Get columns that contain 'Yr' or 'Year'
year_columns = [feature for feature in numerical_columns if 'Yr' in feature or 'Year' in feature]

# Convert year values into age-related features
for col in year_columns:
    df[col] = df['YrSold'] - df[col]
    print(df[col])

# %% [markdown]
# # Feature transformation

# %%
import pandas as pd

# Get numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns

# Identify columns containing zeros
numerical_0s = df.loc[:, (df == 0).any()].select_dtypes(include=['number']).columns

# Remove columns that contain zeros from consideration
numerical_columns = numerical_columns.difference(numerical_0s)

# Calculate skewness for the remaining numerical columns
skewness = df[numerical_columns].skew()

# Set threshold for skewness (e.g., absolute value > 1 indicates high skewness)
skewed_columns = skewness[abs(skewness) > 1]

# Display skewed columns
print("Skewed Columns:")
print(skewed_columns)
# Out:
# Skewed Columns:
# DEGC1PV     -1.357095
# DEGC1SV      2.518575
# DEGC2PV     -1.480677
# DEGC3PV     -1.725213
# DEGC3SV      1.421345
# DEGC4PV     -1.907847
# DEGC5PV     -2.143557
# DEGC5SV      3.169791
# DEGC6PV     -1.500024
# FC1          2.208214
# FC2          2.991171
# FC3          1.077772
# FC5          1.945153
# NM3/H.1SV    5.160289
# NM3/H.2SV    5.116278
# NM3/H.3SV    2.200607
# NM3/H.5SV    2.375605
# TEMP        -1.464523
# mmH2O       -1.032276
# dtype: float64

# %%
import numpy as np

# The list of highly skewed features identified earlier
skew_features = ['NM3/H.1SV', 'NM3/H.2SV', 'NM3/H.3SV', 'NM3/H.5SV', 'TEMP']

# Apply log transformation to each skewed feature
for col in skew_features:
    df[col] = np.log(df[col])
    print(df[col])
# Out:
# 0       8.170469
# 1       8.111628
# 2       7.741968
# 3       8.158802
# 4       7.380879
#           ...
# 3451    7.696213
# 3452    8.058644
# 3453    7.822044
# 3454    7.696213
# 3455    8.111628
# Name: NM3/H.1SV, Length: 3456, dtype: float64
# 0       8.245647
# 1       8.335431
# 2       7.971431
# 3       8.326759
# 4       7.487174
#           ...
# 3451    7.740664
# 3452    8.141190
# 3453    7.987185
# 3454    7.740664
# 3455    8.335431
# Name: NM3/H.2SV, Length: 3456, dtype: float64
# 0       7.983099
# 1       8.467793
# 2       7.817625
# 3       8.288032
# 4       7.364547
#           ...
# 3451    7.713785
# 3452    8.984568
# 3453    7.965546
# 3454    7.713785
# 3455    8.873328
# Name: NM3/H.3SV, Length: 3456, dtype: float64
# 0       7.222566
# 1       7.740230
# 2       7.549609
# 3       7.679714
# 4       6.895683
#           ...
# 3451    7.168580
# 3452    8.592115
# 3453    7.640123
# 3454    7.323831
# 3455    7.873598
# ...

# %%
categorical_columns
# Out:
# Index([], dtype='object')
